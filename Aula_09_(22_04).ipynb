# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolasaalves/Checkpoint-3---Engenharia-de-Software/blob/main/Aula_09_(22_04).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício Prático — Hands-on!
#
# **🎯 App: "Minha Lista de Tarefas" (To-Do List)**
#
# **Contexto:** Modelar e prototipar um mini-app de lista de tarefas usando Arquitetura em Camadas + MVC.

# %% [markdown]
# ## Diagrama no Miro
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Legenda
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Fluxo de Ação:
#
# **Adicionar tarefa**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Parte 2 — Protótipo no Figma
#
# ![image.png](data:image/png;base64,...)
